# %% [markdown]
# # Installation

# %%
# !pip install -q keras-ocr

# %% [markdown]
# # Imports

# %%
import keras_ocr
import matplotlib.pyplot as plt

# %% [markdown]
# # Download Weights

# %%
pipeline = keras_ocr.pipeline.Pipeline()
# Out:
# Looking for /root/.keras-ocr/craft_mlt_25k.h5
# Downloading /root/.keras-ocr/craft_mlt_25k.h5
# Looking for /root/.keras-ocr/crnn_kurapan.h5
# Downloading /root/.keras-ocr/crnn_kurapan.h5

# %% [markdown]
# # Get Images

# %%
images = [
    keras_ocr.tools.read(img) for img in ['ocr1.jpg',
                                          'ocr4.jpg'
    ]
]

# %%
len(images)
# Out:
# 2

# %%
plt.figure(figsize = (10,20))
plt.imshow(images[0])

# %%
plt.figure(figsize = (10,20))
plt.imshow(images[1])

# %% [markdown]
# # Get Predictions

# %%
prediction_groups = pipeline.recognize(images)

# %%
predictions= []

fig, axs = plt.subplots(nrows=len(images), figsize=(10, 20))
for ax, image, predictions in zip(axs, images, prediction_groups):
    keras_ocr.tools.drawAnnotations(image=image, 
                                    predictions=predictions, 
                                    ax=ax)
    predictions.append(predictions)

# %%
for i in range(len(predictions)):
  print(predictions[i][0])
# Out:
# edition
# anniversary
# 25th
# sold
# millioncopes
# over25
# of
# habits
# the
# highly
# effective
# people
# how
# effective
# take
# youp
# are
# the
# peq
# personal
# new
# effeciveness
# quotient
# and
# ourl
# find
# powerful
# lessons
# personal
# change
# in
# o
# aforeword
# by
# with
# jim
# collins
# and
# of
# goodto
# great
# coauthor
# of
# great
# author
# by
# choice
# stephen
# ro
# covey
# ('edition', array([[454.40323 ,  48.701256],
#        [611.0989  ,  34.237045],
#        [613.54614 ,  60.749596],
#        [456.8505  ,  75.213806]], dtype=float32))
