# %%
import numpy as np 
import cv2 as cv
import matplotlib.pyplot as plt

# %%
img = cv.imread("DATA/sammy.jpg")
img = cv.cvtColor(img,cv.COLOR_BGR2RGB)
face = cv.imread("DATA/sammy_face.jpg")
face = cv.cvtColor(face,cv.COLOR_BGR2RGB)

plt.subplot(121)
plt.imshow(img)
plt.subplot(122)
plt.imshow(face)
plt.show()
# plt.imshow()

# %%
#  Image copy 

# imgcopy = img 


methods = ['cv.TM_CCOEFF','cv.TM_CCOEFF_NORMED','cv.TM_CCORR','cv.TM_CCORR_NORMED','cv.TM_SQDIFF','cv.TM_SQDIFF_NORMED']

res = cv.matchTemplate(imgcopy,face,eval(methods[4]))
plt.imshow(res)
plt.imshow(res)
#   res = cv.matchTemplate(imgcopy,face,method)
    
minvalue , maxvalue , minloc , maxloc = cv.minMaxLoc(res)
print(maxloc)

height,width,channel = face.shape
# for i in methods:
#     imgcopy = img.copy()
#     method = eval(i)
#     res = cv.matchTemplate(imgcopy,face,method)
#     minvalue , maxvalue , minloc , maxloc = cv.minMaxLoc(res)
#     if method in [cv.TM_SQDIFF,cv.TM_SQDIFF_NORMED]:
#         topleft = minloc
#     else:
#         topleft = maxloc

    
#     bottomright = (topleft[0]+width,topleft[1]+height)
    
#     ress = cv.rectangle(imgcopy,topleft,bottomright,(255,0,0),10)
    
#     plt.subplot(121)
#     plt.imshow(res)
#     plt.subplot(122)
#     plt.imshow(ress)
    
#     plt.show()
# Out:
# (0, 0)

# %%
# res = cv.matchTemplate(img,face,cv.TM_CCOEFF)
# minvalue , maxvalue , minloc , maxloc = cv.minMaxLoc(res)
    
# maxloc
