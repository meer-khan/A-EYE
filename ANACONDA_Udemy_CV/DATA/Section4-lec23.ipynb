# %%
import numpy as np 
import cv2 as cv 
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-1b22699a8760> in <module>
#       1 import numpy as np
# ----> 2 import cv2 as cv
#       3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'cv2'

# %%
img1 = cv.imread("dog_backpack.jpg")
img1 = cv.cvtColor(img1,cv.COLOR_BGR2RGB)
img2 = cv.imread("watermark_no_copy.png")
img2 = cv.cvtColor(img2,cv.COLOR_BGR2RGB)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-1d5f5459f3d2> in <module>
# ----> 1 img1 = cv.imread("dog_backpack.jpg")
#       2 img1 = cv.cvtColor(img1,cv.COLOR_BGR2RGB)
#       3 img2 = cv.imread("watermark_no_copy.png")
#       4 img2 = cv.cvtColor(img2,cv.COLOR_BGR2RGB)
#
# NameError: name 'cv' is not defined

# %%
type(img2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-c840a30d4e58> in <module>
# ----> 1 type(img2)
#
# NameError: name 'img2' is not defined

# %%
img1.shape[0]
plt.imshow(img1)

# %%
img2.shape
# Out:
# (1280, 1277, 3)

# %%
img11 = cv.resize(img1,(1200,1200 ))
img22 = cv.resize(img2,(1200,1200))

# %%
img3 = cv.addWeighted(img11, 0.8 , img22 , 0.2, 0)

# %%
plt.imshow(img3)

# %%
img11.shape
# Out:
# (1200, 1200, 3)

# %%
img22.shape
# Out:
# (1200, 1200, 3)

# %%
img22 = cv.resize(img22,(600,600))

# %%
img22.shape
# Out:
# (600, 600, 3)

# %%
img11[0:600,0:600] = img22

# %%
plt.imshow(img11)
